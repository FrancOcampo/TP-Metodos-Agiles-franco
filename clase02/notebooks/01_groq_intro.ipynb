# %% [markdown]
# # 01 — Hola Groq desde Python
#
# <a href="https://colab.research.google.com/github/jorgeroa/ia-utn-frsf/blob/main/clase02/notebooks/01_groq_intro.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Objetivo.** Conectarse a un LLM por código (no por UI) y observar tres comportamientos básicos:
# 1. Una consulta simple.
# 2. El efecto de `temperature` en la respuesta.
# 3. El efecto de un `system` prompt en el comportamiento.
#
# **Requisitos.**
# - API key gratuita en https://console.groq.com (registrate con email).
# - En Colab, guardá la key en el panel de "Secrets" con nombre `GROQ_API_KEY` (icono de la llave en la sidebar).

# %%
# %pip install --quiet groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 2.5 MB/s eta 0:00:00

# %% [markdown]
# ## Setup
#
# Si estás en Colab, esto lee la API key del panel de Secrets. Si estás local, exportá `GROQ_API_KEY` antes de abrir Jupyter.

# %%
import os
from groq import Groq

# En Colab:
try:
    from google.colab import userdata
    os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")
except ImportError:
    # Local: asume que ya está exportada
    assert os.environ.get("GROQ_API_KEY"), "Exportá GROQ_API_KEY antes de correr."

client = Groq()
MODELS = {
    "llama_fast":   "llama-3.1-8b-instant",
    "llama_strong": "llama-3.3-70b-versatile",
    "qwen_reason":  "qwen/qwen3-32b",
    "deepseek":     "deepseek-r1-distill-llama-70b",
    "gemma":        "gemma2-9b-it",
}
MODEL = MODELS["llama_strong"]  # cambiá la clave para probar otros modelos

print("Cliente listo, modelo:", MODEL)
# Out:
# Cliente listo, modelo: llama-3.3-70b-versatile

# %% [markdown]
# ## 1. Consulta simple
#
# Mandamos un único mensaje del usuario y leemos la respuesta.

# %%
resp = client.chat.completions.create(
    model=MODEL,
    messages=[{"role": "user", "content": "Explicame en 2 oraciones qué es un LLM."}],
    #messages=[{"role": "user", "content": "Por que no me quiere?"}],
)

print(resp.choices[0].message.content)
# Out:
# Parece que estás pasando por un momento difícil y te sientes herido o confundido. La pregunta "¿Por qué no me quiere?" puede ser muy dolorosa y personal.
#
# Es importante recordar que no hay una respuesta única y universal para esta pregunta, ya que cada persona es única y tiene sus propias razones y sentimientos. Sin embargo, puedo ofrecerte algunas posibles explicaciones y consejos que podrían ayudarte a entender y procesar tus emociones.
#
# **Posibles razones**
#
# 1. **No es personal**: A veces, la falta de interés o cariño no se debe a nada que hayas hecho o no hayas hecho. La otra persona puede estar pasando por un momento difícil en su vida, tener problemas personales o simplemente no estar lista para una relación.
# 2. **Diferencias de personalidad o intereses**: Es posible que tú y la otra persona tengan personalidades o intereses muy diferentes, lo que puede hacer que sea difícil conectar o mantener una relación.
# 3. **Miedo o inseguridad**: La otra persona puede estar asustada o insegura de sus propios sentimientos o de la posibilidad de lastimarte.
# 4. **No es el momento adecuado**: La vida puede ser complicada, y a veces las personas no están en el momento adecuado para una relación.
#
# **Consejos**
#
# 1. **Acepta tus sentimientos**: Es normal sentirse triste, enojado o confundido. Acepta tus emociones y permite que te guíen hacia una comprensión más profunda de ti mismo.
# 2. **No te tomes la falta de interés como un rechazo personal**: Recuerda que la falta de interés no se debe a ti como persona. No te sientas como si no valieras la pena o no fueras lo suficientemente bueno.
# 3. **Busca apoyo**: Habla con amigos, familiares o un profesional de la salud mental sobre tus sentimientos y experiencias. Ellos pueden ofrecerte consejos y apoyo valioso.
# 4. **Enfócate en ti mismo**: Utiliza este momento para conocer más sobre ti mismo, tus intereses y tus valores. Aprende a amarte y aceptarte tal como eres.
#
# Recuerda que el amor y el cariño son complejos y no siempre se pueden explicar de manera lógica. Lo importante es que te cuides a ti mismo y sigas adelante, sabiendo que hay personas que te aman y te aprecian tal como eres. ¿Hay algo más en lo que te gustaría hablar o algo específico que te preocupe? Estoy aquí para escucharte.

# %% [markdown]
# ## 2. Efecto de `temperature`
#
# La misma pregunta, dos veces, con temperaturas distintas. Observá cómo cambia el estilo de la respuesta.

# %%
PROMPT = "Escribime un haiku sobre los lunes."

for temp in [0.1, 1.0]:
    resp = client.chat.completions.create(
        model=MODEL,
        messages=[{"role": "user", "content": PROMPT}],
        temperature=temp,
    )
    print(f"--- temperature = {temp} ---")
    print(resp.choices[0].message.content)
    print()

# %% [markdown]
# ## 3. Cambiar el "carácter" con un `system` prompt
#
# El system prompt define el rol del modelo antes de cualquier interacción del usuario.

# %%
PIRATA = "Sos un pirata del Caribe del siglo XVII. Hablás siempre en primera persona y usás expresiones piratas."

resp = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": PIRATA},
        {"role": "user", "content": "¿Cómo declaro un array en Python?"},
    ],
    temperature=0.6,
)

print(resp.choices[0].message.content)

# %% [markdown]
# ## Para experimentar después
#
# - Cambiá el `system` prompt: profesor de física, abogado, chef.
# - Combiná `system` + `temperature` baja → asistente técnico predecible.
# - Probá pasar varios mensajes en `messages` simulando una conversación.
#
# > El próximo notebook (`03_sampling_params`) profundiza en `temperature`, `top_p` y los efectos del sampling.
